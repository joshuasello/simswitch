# %% [markdown]
# # Double Pulse Test Comparative Analysis
#
# Author: Joshua Sello
#
# Institutions: Reutlingen Hochschule, and Stellenbosch University

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from pathlib import Path
from switchsim import *


simulation_output_directory_path = Path("simulation_outputs")
simulation_results_directory_path = Path("simulation_results")

os.getcwd()
# Out:
# 'C:\\Users\\joshu\\Development\\university-development\\switchsim\\notebooks'

# %% [markdown]
# ## 1. Load Simulation Config

# %%
config = load_config_from_yaml("../workspace/dpt_gan_simulation.yaml")
config
# Out:
# ConfigData(setup=ConfigSetupData(output_field_mapping=DoublePulseTestOutputFields(time='time', dut_gate_voltage='V(dut_gate_voltage)', dut_drain_voltage='V(dut_drain_voltage)', dut_source_voltage='V(dut_source_voltage)', dut_drain_current='Ix(dut:DRAININ)'), default_parameters=DoublePulseTestParameters(leading_duration=5e-06, lagging_duration=5e-06, load_supply_voltage=400.0, load_test_current=4.0, first_pulse_duration=5e-05, second_pulse_duration=5e-06, off_duration=5e-06, on_gate_resistance=10.0, dut_case_temperature=25.0, max_timestep=5e-05), ltspice_executable_file_path='C:\\Users\\joshu\\Development\\university-development\\switchsim\\res\\LTspice.exe'), runs={'double_pulse_test_gan_gs66516t': RunData(source_file_path=WindowsPath('C:/Users/joshu/Development/university-development/switchsim/workspace/double_pulse_test_gan_gs66516t.asc'), parameters_to_sweep={'load_test_current': SweptParameterData(start=5.0, end=25.0, step=5.0)})}, results=['turn_on_loss', 'turn_off_loss'])

# %% [markdown]
# ## 2. Execute or Load Simulation Outputs

# %%
if not simulation_output_directory_path.exists():
    per_run_outputs = run_double_pulse_test_simulations(
        runs=config.runs,
        default_parameters=config.setup.default_parameters,
        output_field_mapping=config.setup.output_field_mapping,
        ltspice_executable_file_path=config.setup.ltspice_executable_file_path,
        verbose=True,
    )
    
    save_double_pulse_test_simulation_outputs(
        output_directory_path=simulation_output_directory_path,
        per_run_outputs=per_run_outputs,
    )
else:
    per_run_outputs = load_double_pulse_test_simulation_outputs(
        output_directory_path=simulation_output_directory_path,
    )
# Out:
# Run 1 / 1 - double_pulse_test_gan_gs66516t: C:\Users\joshu\Development\university-development\switchsim\workspace\double_pulse_test_gan_gs66516t.asc
# 		 - 1 / 4 Executing...
# 		 - 1 / 4 Executed in  73.04 seconds
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-12-09_f9884a88-f997-416e-a976-8c8338391165.asc
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-12-09_f9884a88-f997-416e-a976-8c8338391165.log
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-12-09_f9884a88-f997-416e-a976-8c8338391165.net
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-12-09_f9884a88-f997-416e-a976-8c8338391165.raw
# 		 - 2 / 4 Executing...
# 		 - 2 / 4 Executed in  6.72 seconds
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-26_c165dd6d-12af-4a1e-9f4a-459015f812d3.asc
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-26_c165dd6d-12af-4a1e-9f4a-459015f812d3.log
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-26_c165dd6d-12af-4a1e-9f4a-459015f812d3.net
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-26_c165dd6d-12af-4a1e-9f4a-459015f812d3.raw
# 		 - 3 / 4 Executing...
# 		 - 3 / 4 Executed in  20.29 seconds
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-33_03c42f2e-61ba-45eb-b310-20325552ef8f.asc
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-33_03c42f2e-61ba-45eb-b310-20325552ef8f.log
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-33_03c42f2e-61ba-45eb-b310-20325552ef8f.net
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-33_03c42f2e-61ba-45eb-b310-20325552ef8f.raw
# 		 - 4 / 4 Executing...
# 		 - 4 / 4 Executed in  5.35 seconds
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-54_5fc97ca4-7d51-4362-a339-27f11a282889.asc
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-54_5fc97ca4-7d51-4362-a339-27f11a282889.log
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-54_5fc97ca4-7d51-4362-a339-27f11a282889.net
# Deleted: C:\Users\joshu\Development\university-development\switchsim\workspace\2025-02-10_15-13-54_5fc97ca4-7d51-4362-a339-27f11a282889.raw
# 	 - load_test_current: 2 rows

# %%
per_run_outputs
# Out:
# {'double_pulse_test_gan_gs66516t': {'load_test_current': [(DoublePulseTestParameters(leading_duration=5e-06, lagging_duration=5e-06, load_supply_voltage=400.0, load_test_current=np.float64(5.0), first_pulse_duration=5e-05, second_pulse_duration=5e-06, off_duration=5e-06, on_gate_resistance=10.0, dut_case_temperature=25.0, max_timestep=5e-05),
#                      time  dut_gate_voltage  dut_drain_voltage  \
#     0        0.000000e+00      3.575341e-07         400.000000
#     1        5.000000e-10      3.574887e-07         400.000000
#     2        1.000000e-09      3.574835e-07         400.000000
#     3        2.000000e-09      3.574969e-07         400.000000
#     4        4.000000e-09      3.574987e-07         400.000000
#     ...               ...               ...                ...
#     1052853  6.589226e-05      3.580475e-07         400.880035
#     1052854  6.635102e-05      3.580441e-07         400.880035
#     1052855  6.712956e-05      3.580457e-07         400.880035
#     1052856  6.850212e-05      3.580450e-07         400.880035
#     1052857  7.000000e-05      3.580457e-07         400.880035
#
#              dut_source_voltage  dut_drain_current  time_differentials  \
#     0                       0.0       2.000015e-07        0.000000e+00
#     1                       0.0       1.999912e-07        5.000000e-10
#     2                       0.0       1.999878e-07        5.000000e-10
#     3                       0.0       1.999923e-07        1.000000e-09
#     4                       0.0       2.000073e-07        2.000000e-09
#     ...                     ...                ...                 ...
#     1052853                 0.0       2.003458e-07        2.616507e-07
#     1052854                 0.0       2.005077e-07        4.587637e-07
#     1052855                 0.0       2.002031e-07        7.785347e-07
#     1052856                 0.0       2.004374e-07        1.372566e-06
#     1052857                 0.0       2.006272e-07        1.497880e-06
#
#              dut_drain_source_voltage  dut_drain_source_power  \
#     0                      400.000000                 0.00008
#     1                      400.000000                 0.00008
#     2                      400.000000                 0.00008
#     3                      400.000000                 0.00008
#     4                      400.000000                 0.00008
#     ...                           ...                     ...
#     1052853                400.880035                 0.00008
#     1052854                400.880035                 0.00008
#     1052855                400.880035                 0.00008
#     1052856                400.880035                 0.00008
#     1052857                400.880035                 0.00008
#
#              dut_drain_source_energy  dut_drain_source_resistance
#     0                   0.000000e+00                 1.999985e+09
#     1                   3.999824e-14                 2.000088e+09
#     2                   3.999756e-14                 2.000122e+09
#     3                   7.999692e-14                 2.000077e+09
#     4                   1.600058e-13                 1.999927e+09
#     ...                          ...                          ...
#     1052853             2.101438e-11                 2.000941e+09
#     1052854             3.687521e-11                 1.999325e+09
#     1052855             6.248319e-11                 2.002367e+09
#     1052856             1.102875e-10                 2.000026e+09
#     1052857             1.204706e-10                 1.998134e+09
#
#     [1052858 rows x 10 columns]),
#    (DoublePulseTestParameters(leading_duration=5e-06, lagging_duration=5e-06, load_supply_voltage=400.0, load_test_current=np.float64(10.0), first_pulse_duration=5e-05, second_pulse_duration=5e-06, off_duration=5e-06, on_gate_resistance=10.0, dut_case_temperature=25.0, max_timestep=5e-05),
#                    time  dut_gate_voltage  dut_drain_voltage  dut_source_voltage  \
#     0      0.000000e+00      3.575341e-07         400.000000                 0.0
#     1      5.000000e-10      3.575154e-07         400.000000                 0.0
#     2      1.000000e-09      3.575133e-07         400.000000                 0.0
#     3      2.000000e-09      3.575240e-07         400.000000                 0.0
#     4      4.000000e-09      3.575353e-07         400.000000                 0.0
#     ...             ...               ...                ...                 ...
#     67487  6.792575e-05      3.574502e-07         400.897827                 0.0
#     67488  6.811346e-05      3.575954e-07         400.897827                 0.0
#     67489  6.848887e-05      3.580553e-07         400.897827                 0.0
#     67490  6.923971e-05      3.580552e-07         400.897827                 0.0
#     67491  7.000000e-05      3.580553e-07         400.897827                 0.0
#
#            dut_drain_current  time_differentials  dut_drain_source_voltage  \
#     0           1.998560e-07        0.000000e+00                400.000000
#     1           1.998907e-07        5.000000e-10                400.000000
#     2           1.999023e-07        5.000000e-10                400.000000
#     3           1.999037e-07        1.000000e-09                400.000000
#     4           1.999033e-07        2.000000e-09                400.000000
#     ...                  ...                 ...                       ...
#     67487       2.000697e-07        1.330096e-06                400.897827
#     67488       2.001714e-07        1.877124e-07                400.897827
#     67489       2.002731e-07        3.754103e-07                400.897827
#     67490       2.002727e-07        7.508352e-07                400.897827
#     67491       2.013112e-07        7.602939e-07                400.897827
#
#            dut_drain_source_power  dut_drain_source_energy  \
#     0                    0.000080             0.000000e+00
#     1                    0.000080             3.997814e-14
#     2                    0.000080             3.998045e-14
#     3                    0.000080             7.996148e-14
#     4                    0.000080             1.599226e-13
#     ...                       ...                      ...
#     67487                0.000080             1.066837e-10
#     67488                0.000080             1.506360e-11
#     67489                0.000080             3.014134e-11
#     67490                0.000080             6.028371e-11
#     67491                0.000081             6.135969e-11
#
#            dut_drain_source_resistance
#     0                     2.001441e+09
#     1                     2.001094e+09
#     2                     2.000978e+09
#     3                     2.000964e+09
#     4                     2.000968e+09
#     ...                            ...
#     67487                 2.003790e+09
#     67488                 2.002772e+09
#     67489                 2.001755e+09
#     67490                 2.001760e+09
#     67491                 1.991433e+09
#
#     [67492 rows x 10 columns]),
#    (DoublePulseTestParameters(leading_duration=5e-06, lagging_duration=5e-06, load_supply_voltage=400.0, load_test_current=np.float64(15.0), first_pulse_duration=5e-05, second_pulse_duration=5e-06, off_duration=5e-06, on_gate_resistance=10.0, dut_case_temperature=25.0, max_timestep=5e-05),
#                     time  dut_gate_voltage  dut_drain_voltage  dut_source_voltage  \
#     0       0.000000e+00      3.575341e-07         400.000000                 0.0
#     1       5.000000e-10      3.575557e-07         400.000000                 0.0
#     2       1.000000e-09      3.575741e-07         400.000000                 0.0
#     3       2.000000e-09      3.575709e-07         400.000000                 0.0
#     4       4.000000e-09      3.575624e-07         400.000000                 0.0
#     ...              ...               ...                ...                 ...
#     205391  6.654079e-05      3.580625e-07         400.908264                 0.0
#     205392  6.681146e-05      3.580611e-07         400.908264                 0.0
#     205393  6.735279e-05      3.580611e-07         400.908264                 0.0
#     205394  6.843546e-05      3.580611e-07         400.908264                 0.0
#     205395  7.000000e-05      3.580611e-07         400.908264                 0.0
#
#             dut_drain_current  time_differentials  dut_drain_source_voltage  \
#     0            2.004090e-07        0.000000e+00                400.000000
#     1            2.004849e-07        5.000000e-10                400.000000
#     2            2.005102e-07        5.000000e-10                400.000000
#     3            2.005161e-07        1.000000e-09                400.000000
#     4            2.005305e-07        2.000000e-09                400.000000
#     ...                   ...                 ...                       ...
#     205391       2.005788e-07        1.353328e-07                400.908264
#     205392       2.002271e-07        2.706729e-07                400.908264
#     205393       2.001567e-07        5.413312e-07                400.908264
#     205394       2.001106e-07        1.082670e-06                400.908264
#     205395       2.002052e-07        1.564542e-06                400.908264
#
#             dut_drain_source_power  dut_drain_source_energy  \
#     0                      0.00008             0.000000e+00
#     1                      0.00008             4.009698e-14
#     2                      0.00008             4.010204e-14
#     3                      0.00008             8.020644e-14
#     4                      0.00008             1.604244e-13
#     ...                        ...                      ...
#     205391                 0.00008             1.088261e-11
#     205392                 0.00008             2.172764e-11
#     205393                 0.00008             4.343885e-11
#     205394                 0.00008             8.685828e-11
#     205395                 0.00008             1.255763e-10
#
#             dut_drain_source_resistance
#     0                      1.995919e+09
#     1                      1.995163e+09
#     2                      1.994911e+09
#     3                      1.994852e+09
#     4                      1.994709e+09
#     ...                             ...
#     205391                 1.998757e+09
#     205392                 2.002268e+09
#     205393                 2.002972e+09
#     205394                 2.003433e+09
#     205395                 2.002486e+09
#
#     [205396 rows x 10 columns]),
#    (DoublePulseTestParameters(leading_duration=5e-06, lagging_duration=5e-06, load_supply_voltage=400.0, load_test_current=np.float64(20.0), first_pulse_duration=5e-05, second_pulse_duration=5e-06, off_duration=5e-06, on_gate_resistance=10.0, dut_case_temperature=25.0, max_timestep=5e-05),
#                    time  dut_gate_voltage  dut_drain_voltage  dut_source_voltage  \
#     0      0.000000e+00      3.575341e-07         400.000000                 0.0
#     1      5.000000e-10      3.575261e-07         400.000000                 0.0
#     2      1.000000e-09      3.575252e-07         400.000000                 0.0
#     3      2.000000e-09      3.575323e-07         400.000000                 0.0
#     4      4.000000e-09      3.575411e-07         400.000000                 0.0
#     ...             ...               ...                ...                 ...
#     56157  6.600132e-05      3.580652e-07         400.915649                 0.0
#     56158  6.648977e-05      3.580652e-07         400.915649                 0.0
#     56159  6.714105e-05      3.580653e-07         400.915649                 0.0
#     56160  6.844362e-05      3.580653e-07         400.915649                 0.0
#     56161  7.000000e-05      3.580653e-07         400.915649                 0.0
#
#            dut_drain_current  time_differentials  dut_drain_source_voltage  \
#     0           2.002926e-07        0.000000e+00                400.000000
#     1           2.003404e-07        5.000000e-10                400.000000
#     2           2.003564e-07        5.000000e-10                400.000000
#     3           2.003365e-07        1.000000e-09                400.000000
#     4           2.002822e-07        2.000000e-09                400.000000
#     ...                  ...                 ...                       ...
#     56157       2.008661e-07        2.849411e-07                400.915649
#     56158       2.005860e-07        4.884569e-07                400.915649
#     56159       2.002586e-07        6.512782e-07                400.915649
#     56160       2.000336e-07        1.302564e-06                400.915649
#     56161       2.002052e-07        1.556386e-06                400.915649
#
#            dut_drain_source_power  dut_drain_source_energy  \
#     0                    0.000080             0.000000e+00
#     1                    0.000080             4.006809e-14
#     2                    0.000080             4.007128e-14
#     3                    0.000080             8.013459e-14
#     4                    0.000080             1.602258e-13
#     ...                       ...                      ...
#     56157                0.000081             2.294641e-11
#     56158                0.000080             3.928076e-11
#     56159                0.000080             5.228905e-11
#     56160                0.000080             1.044612e-10
#     56161                0.000080             1.249239e-10
#
#            dut_drain_source_resistance
#     0                     1.997079e+09
#     1                     1.996601e+09
#     2                     1.996442e+09
#     3                     1.996641e+09
#     4                     1.997182e+09
#     ...                            ...
#     56157                 1.995934e+09
#     56158                 1.998722e+09
#     56159                 2.001990e+09
#     56160                 2.004242e+09
#     56161                 2.002523e+09
#
#     [56162 rows x 10 columns])]}}

# %% [markdown]
# ## 3. Process Simulation Outputs

# %%
per_run_results = process_double_pulse_simulation_outputs(
    per_run_outputs=per_run_outputs,
    selected_results=config.results,
)
per_run_results
# Out:
# {'double_pulse_test_gan_gs66516t': {'load_test_current':    leading_duration  lagging_duration  load_supply_voltage  load_test_current  \
#   0          0.000005          0.000005                400.0                5.0
#   1          0.000005          0.000005                400.0               10.0
#   2          0.000005          0.000005                400.0               15.0
#   3          0.000005          0.000005                400.0               20.0
#
#      first_pulse_duration  second_pulse_duration  off_duration  \
#   0               0.00005               0.000005      0.000005
#   1               0.00005               0.000005      0.000005
#   2               0.00005               0.000005      0.000005
#   3               0.00005               0.000005      0.000005
#
#      on_gate_resistance  dut_case_temperature  max_timestep  turn_off_loss  \
#   0                10.0                  25.0       0.00005       0.000085
#   1                10.0                  25.0       0.00005       0.000571
#   2                10.0                  25.0       0.00005       0.000652
#   3                10.0                  25.0       0.00005       0.001119
#
#      turn_on_loss
#   0      0.000012
#   1      0.000027
#   2      0.000049
#   3      0.001402  }}

# %%
per_run_results["double_pulse_test_gan_gs66516t"]["load_test_current"]
# Out:
#    leading_duration  lagging_duration  load_supply_voltage  load_test_current  \
# 0          0.000005          0.000005                400.0                5.0
# 1          0.000005          0.000005                400.0               10.0
# 2          0.000005          0.000005                400.0               15.0
# 3          0.000005          0.000005                400.0               20.0
#
#    first_pulse_duration  second_pulse_duration  off_duration  \
# 0               0.00005               0.000005      0.000005
# 1               0.00005               0.000005      0.000005
# 2               0.00005               0.000005      0.000005
# 3               0.00005               0.000005      0.000005
#
#    on_gate_resistance  dut_case_temperature  max_timestep  turn_off_loss  \
# 0                10.0                  25.0       0.00005       0.000085
# 1                10.0                  25.0       0.00005       0.000571
# 2                10.0                  25.0       0.00005       0.000652
# 3                10.0                  25.0       0.00005       0.001119
#
#    turn_on_loss
# 0      0.000012
# 1      0.000027
# 2      0.000049
# 3      0.001402

# %%
plot_parameter_results(
    results=per_run_results,
    parameter="load_test_current",
    title="Turn On and Turn Off Energy Loss vs Load Current",
    xlabel="Load Current (A)",
    ylabel="Energy Loss (uJ)",
    per_result_plot_data={
        "turn_on_loss": ResultPlotData(
            label="Turn On Losses",
            marker="o",
        ),
        "turn_off_loss": ResultPlotData(
            label="Turn Off Losses",
            marker="o",
            linestyle="--",
        ),
    },
    y_multiplier = 1e6,
)
